# %% [markdown]
# <a href="https://colab.research.google.com/github/ompatel420/ML-Practicals/blob/main/ML_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset =pd.read_csv('/content/drive/MyDrive/ML/Dataset/zoo.csv')
dataset
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
outside_data = pd.DataFrame({
    'animal': ['giraffe', 'giraffe', 'hippo', 'lion'],
    'uniq_id': [1023, 1024, 1025,999],
    'water_need': [700, 750, 800,123]
})
display(outside_data.head())
# Out:
#     animal  uniq_id  water_need
# 0  giraffe     1023         700
# 1  giraffe     1024         750
# 2    hippo     1025         800
# 3     lion      999         123

# %%
combined_dataset = pd.concat([dataset, outside_data], ignore_index=True)
display(combined_dataset)
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410
# 22   giraffe     1023         700
# 23   giraffe     1024         750
# 24     hippo     1025         800
# 25      lion      999         123

# %%
dataset.sort_values('water_need')
# Out:
#       animal  uniq_id  water_need
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 15      lion     1016         420
# 20  kangaroo     1021         430
# 17      lion     1018         500
# 0   elephant     1001         500
# 2   elephant     1003         550
# 1   elephant     1002         600
# 16      lion     1017         600

# %%
merged_dataset_outer = pd.merge(dataset, outside_data, how='outer')
display(merged_dataset_outer)
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3    giraffe     1023         700
# 4    giraffe     1024         750
# 5      hippo     1025         800
# 6   kangaroo     1020         410
# 7   kangaroo     1021         430
# 8   kangaroo     1022         410
# 9       lion      999         123
# 10      lion     1016         420
# 11      lion     1017         600
# 12      lion     1018         500
# 13      lion     1019         390
# 14     tiger     1004         300
# 15     tiger     1005         320
# 16     tiger     1006         330
# 17     tiger     1007         290
# 18     tiger     1008         310
# 19     zebra     1009         200
# 20     zebra     1010         220
# 21     zebra     1011         240
# 22     zebra     1012         230
# 23     zebra     1013         220
# 24     zebra     1014         100
# 25     zebra     1015          80

# %%
dataset.sort_values('water_need')
# Out:
#       animal  uniq_id  water_need
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 15      lion     1016         420
# 20  kangaroo     1021         430
# 17      lion     1018         500
# 0   elephant     1001         500
# 2   elephant     1003         550
# 1   elephant     1002         600
# 16      lion     1017         600

# %%
merged_dataset_inner = pd.merge(dataset, outside_data, how='inner')
display(merged_dataset_inner)
# Out:
# Empty DataFrame
# Columns: [animal, uniq_id, water_need]
# Index: []

# %%
df4=pd.read_excel("/content/drive/MyDrive/ML/Dataset/Covid cases in India.xlsx")
df4
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 0      1.0                               Maharashtra                20228
# 1      2.0                                   Gujarat                 7797
# 2      3.0                                     Delhi                 6542
# 3      4.0                                Tamil Nadu                 6535
# 4      5.0                                 Rajasthan                 3741
# 5      6.0                            Madhya Pradesh                 3457
# 6      7.0                             Uttar Pradesh                 3373
# 7      8.0                            Andhra Pradesh                 1930
# 8      9.0                               West Bengal                 1786
# 9     10.0                                    Punjab                 1762
# 10    11.0                                 Telangana                 1163
# 11    12.0                         Jammu and Kashmir                  836
# 12    13.0                                 Karnataka                  794
# 13    14.0                                   Haryana                  675
# 14    15.0                                     Bihar                  629
# 15    16.0                                    Kerala                  506
# 16    17.0                                    Odisha                  352
# 17    18.0                                Chandigarh                  169
# 18    19.0                                 Jharkhand                  156
# 19    20.0                                   Tripura                  135
# 20    21.0                               Uttarakhand                   67
# 21    22.0                                     Assam                   62
# 22    23.0                              Chhattisgarh                   59
# 23    24.0                          Himachal Pradesh                   52
# 24    25.0                                    Ladakh                   42
# 25    26.0               Andaman and Nicobar Islands                   33
# 26    27.0                                 Meghalaya                   13
# 27    28.0                                Puducherry                   10
# 28    29.0                                       Goa                    7
# 29    30.0                                   Manipur                    2
# 30    31.0                                   Mizoram                    1
# 31    32.0                         Arunachal Pradesh                    1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
# 33     NaN                                     Total                62916
#
#     Active  Recovered  Deaths
# 0    15649       3800     779
# 1     5234       2091     472
# 2     4454       2020      68
# 3     4667       1824      44
# 4     1458       2176     107
# 5     1766       1480     211
# 6     1800       1499      74
# 7      999        887      44
# 8     1243        372     171
# 9     1574        157      31
# 10     382        751      30
# 11     459        368       9
# 12     377        386      30
# 13     376        290       9
# 14     306        318       5
# 15      17        485       4
# 16     281         68       3
# 17     143         24       2
# 18      75         78       3
# 19     133          2       0
# 20      20         46       1
# 21      26         35       1
# 22      16         43       0
# 23      11         35       3
# 24      24         18       0
# 25       0         33       0
# 26       2         10       1
# 27       2          8       0
# 28       0          7       0
# 29       0          2       0
# 30       0          1       0
# 31       0          1       0
# 32       1          0       0
# 33   41495      19315    2102

# %%
print(type(df4))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df4.columns
# Out:
# Index(['S. No.', 'Name of State / UT', 'TotalConfirmedCases', 'Active',
#        'Recovered', 'Deaths'],
#       dtype='object')

# %%
df4.shape
# Out:
# (34, 6)

# %%
df4.sample(2)
# Out:
#    S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 9    10.0             Punjab                 1762    1574        157      31
# 1     2.0            Gujarat                 7797    5234       2091     472

# %%
df4.head(3)
# Out:
#    S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 0     1.0        Maharashtra                20228   15649       3800     779
# 1     2.0            Gujarat                 7797    5234       2091     472
# 2     3.0              Delhi                 6542    4454       2020      68

# %%
df4[['Active','Recovered','Deaths']]
# Out:
#     Active  Recovered  Deaths
# 0    15649       3800     779
# 1     5234       2091     472
# 2     4454       2020      68
# 3     4667       1824      44
# 4     1458       2176     107
# 5     1766       1480     211
# 6     1800       1499      74
# 7      999        887      44
# 8     1243        372     171
# 9     1574        157      31
# 10     382        751      30
# 11     459        368       9
# 12     377        386      30
# 13     376        290       9
# 14     306        318       5
# 15      17        485       4
# 16     281         68       3
# 17     143         24       2
# 18      75         78       3
# 19     133          2       0
# 20      20         46       1
# 21      26         35       1
# 22      16         43       0
# 23      11         35       3
# 24      24         18       0
# 25       0         33       0
# 26       2         10       1
# 27       2          8       0
# 28       0          7       0
# 29       0          2       0
# 30       0          1       0
# 31       0          1       0
# 32       1          0       0
# 33   41495      19315    2102

# %%
df5=df4.iloc[[2,6,7]]
df5
# Out:
#    S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 2     3.0              Delhi                 6542    4454       2020      68
# 6     7.0      Uttar Pradesh                 3373    1800       1499      74
# 7     8.0     Andhra Pradesh                 1930     999        887      44

# %%
df4[df4['Active']>500]
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 2      3.0              Delhi                 6542    4454       2020      68
# 3      4.0         Tamil Nadu                 6535    4667       1824      44
# 4      5.0          Rajasthan                 3741    1458       2176     107
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 6      7.0      Uttar Pradesh                 3373    1800       1499      74
# 7      8.0     Andhra Pradesh                 1930     999        887      44
# 8      9.0        West Bengal                 1786    1243        372     171
# 9     10.0             Punjab                 1762    1574        157      31
# 33     NaN              Total                62916   41495      19315    2102

# %%
df4[(df4['Active']>500) & (df4['Deaths']>100)]
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 4      5.0          Rajasthan                 3741    1458       2176     107
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 8      9.0        West Bengal                 1786    1243        372     171
# 33     NaN              Total                62916   41495      19315    2102

# %%
df4.sort_values(by=['Deaths'],ascending=[False]).head(5)
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 33     NaN              Total                62916   41495      19315    2102
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 8      9.0        West Bengal                 1786    1243        372     171

# %%
df4.sort_values(by=['Deaths'],ascending=[True]).head(5)
# Out:
#     S. No.           Name of State / UT  TotalConfirmedCases  Active  \
# 24    25.0                       Ladakh                   42      24
# 25    26.0  Andaman and Nicobar Islands                   33       0
# 27    28.0                   Puducherry                   10       2
# 28    29.0                          Goa                    7       0
# 30    31.0                      Mizoram                    1       0
#
#     Recovered  Deaths
# 24         18       0
# 25         33       0
# 27          8       0
# 28          7       0
# 30          1       0

# %%
df4.dropna()
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 0      1.0                               Maharashtra                20228
# 1      2.0                                   Gujarat                 7797
# 2      3.0                                     Delhi                 6542
# 3      4.0                                Tamil Nadu                 6535
# 4      5.0                                 Rajasthan                 3741
# 5      6.0                            Madhya Pradesh                 3457
# 6      7.0                             Uttar Pradesh                 3373
# 7      8.0                            Andhra Pradesh                 1930
# 8      9.0                               West Bengal                 1786
# 9     10.0                                    Punjab                 1762
# 10    11.0                                 Telangana                 1163
# 11    12.0                         Jammu and Kashmir                  836
# 12    13.0                                 Karnataka                  794
# 13    14.0                                   Haryana                  675
# 14    15.0                                     Bihar                  629
# 15    16.0                                    Kerala                  506
# 16    17.0                                    Odisha                  352
# 17    18.0                                Chandigarh                  169
# 18    19.0                                 Jharkhand                  156
# 19    20.0                                   Tripura                  135
# 20    21.0                               Uttarakhand                   67
# 21    22.0                                     Assam                   62
# 22    23.0                              Chhattisgarh                   59
# 23    24.0                          Himachal Pradesh                   52
# 24    25.0                                    Ladakh                   42
# 25    26.0               Andaman and Nicobar Islands                   33
# 26    27.0                                 Meghalaya                   13
# 27    28.0                                Puducherry                   10
# 28    29.0                                       Goa                    7
# 29    30.0                                   Manipur                    2
# 30    31.0                                   Mizoram                    1
# 31    32.0                         Arunachal Pradesh                    1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
#
#     Active  Recovered  Deaths
# 0    15649       3800     779
# 1     5234       2091     472
# 2     4454       2020      68
# 3     4667       1824      44
# 4     1458       2176     107
# 5     1766       1480     211
# 6     1800       1499      74
# 7      999        887      44
# 8     1243        372     171
# 9     1574        157      31
# 10     382        751      30
# 11     459        368       9
# 12     377        386      30
# 13     376        290       9
# 14     306        318       5
# 15      17        485       4
# 16     281         68       3
# 17     143         24       2
# 18      75         78       3
# 19     133          2       0
# 20      20         46       1
# 21      26         35       1
# 22      16         43       0
# 23      11         35       3
# 24      24         18       0
# 25       0         33       0
# 26       2         10       1
# 27       2          8       0
# 28       0          7       0
# 29       0          2       0
# 30       0          1       0
# 31       0          1       0
# 32       1          0       0

# %%
df4['TotalConfirmedCases'].mean()
# Out:
# np.float64(3700.9411764705883)

# %%
df4['total']=df4['Active']+df4['Recovered']+df4['Deaths']
df4.sample(5)
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 25    26.0               Andaman and Nicobar Islands                   33
# 9     10.0                                    Punjab                 1762
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
# 30    31.0                                   Mizoram                    1
# 4      5.0                                 Rajasthan                 3741
#
#     Active  Recovered  Deaths  total
# 25       0         33       0     33
# 9     1574        157      31   1762
# 32       1          0       0      1
# 30       0          1       0      1
# 4     1458       2176     107   3741

# %%
df4.fillna(df4.mean(numeric_only=True)).tail(5)
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 29    30.0                                   Manipur                    2
# 30    31.0                                   Mizoram                    1
# 31    32.0                         Arunachal Pradesh                    1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
# 33    17.0                                     Total                62916
#
#     Active  Recovered  Deaths  total
# 29       0          2       0      2
# 30       0          1       0      1
# 31       0          1       0      1
# 32       1          0       0      1
# 33   41495      19315    2102  62912

# %%
df4.fillna(df4.median(numeric_only=True)).tail(5)
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 29    30.0                                   Manipur                    2
# 30    31.0                                   Mizoram                    1
# 31    32.0                         Arunachal Pradesh                    1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
# 33    17.0                                     Total                62916
#
#     Active  Recovered  Deaths  total
# 29       0          2       0      2
# 30       0          1       0      1
# 31       0          1       0      1
# 32       1          0       0      1
# 33   41495      19315    2102  62912

# %%
df4.fillna(df4.mode(numeric_only=True)).tail(5)
# Out:
#     S. No.                        Name of State / UT  TotalConfirmedCases  \
# 29    30.0                                   Manipur                    2
# 30    31.0                                   Mizoram                    1
# 31    32.0                         Arunachal Pradesh                    1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu                    1
# 33     NaN                                     Total                62916
#
#     Active  Recovered  Deaths  total
# 29       0          2       0      2
# 30       0          1       0      1
# 31       0          1       0      1
# 32       1          0       0      1
# 33   41495      19315    2102  62912

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ay=sns.barplot(y=df4["Name of State / UT"],x=df4["Active"])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,5))
graph=sns.barplot(x=df4["Name of State / UT"],y=df4["Active"])
graph.set_xticklabels(df4["Name of State / UT"],rotation=45,ha="right")
plt.show()
# Out:
# /tmp/ipykernel_503/3956517130.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   graph.set_xticklabels(df4["Name of State / UT"],rotation=45,ha="right")
